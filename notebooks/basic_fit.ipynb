# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
data = np.array([0.2, 0.4, 0.5, 0.6, 0.8, 0.9, 1.1, 1.3, 1.5, 1.6])
plt.hist(data, bins=15, density=True)
plt.show()
